# %% [markdown]
# **Prepare environment:**

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import matplotlib.pyplot as plt
from pathlib import Path

plt.rcParams['figure.figsize'] = [14, 8]

work_dir = Path.cwd().parent.parent
sys.path.append(str(work_dir))
# print(sys.path)

from pytracking.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from pytracking.evaluation import get_dataset, trackerlist

# %% [markdown]
# **For frame-based evaluation with pytracking's trackers:**

# %%
pytracking_trackers_frame = trackerlist('dimp', 'dimp18', range(1)) + \
                trackerlist('dimp', 'dimp18_esot500', range(1)) + \
                trackerlist('dimp', 'dimp50', range(1)) + \
                trackerlist('dimp', 'dimp50_esot500', range(1)) + \
                trackerlist('kys', 'default', range(1)) + \
                trackerlist('kys', 'esot500', range(1)) + \
                trackerlist('atom', 'default', range(1)) + \
                trackerlist('atom', 'esot500', range(1)) + \
                trackerlist('tomp', 'tomp50', range(1)) + \
                trackerlist('tomp', 'tomp50_esot500', range(1)) + \
                trackerlist('tomp', 'tomp101', range(1)) + \
                trackerlist('tomp', 'tomp101_esot500', range(1)) + \
                trackerlist('dimp', 'prdimp18', range(1)) + \
                trackerlist('dimp', 'prdimp50', range(1)) + \
                trackerlist('keep_track','default',range(1)) + \
                trackerlist('rts', 'rts50', range(1)) + \
                trackerlist('egt', 'egt', range(1))

trackers = []
trackers.extend(pytracking_trackers_frame)

# %%
# Frame-based evaluation - Pytracking - 500FPS - 2ms

dataset_name = 'esot_500_2'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 500FPS - 20ms

dataset_name = 'esot_500_20'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 500FPS - 50ms

dataset_name = 'esot_500_50'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 500FPS - 100ms

dataset_name = 'esot_500_100'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 500FPS - 150ms

dataset_name = 'esot_500_150'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 250FPS - 2ms

dataset_name = 'esot_250_2'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 250FPS - 20ms

dataset_name = 'esot_250_20'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 250FPS - 50ms

dataset_name = 'esot_250_50'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 250FPS - 100ms

dataset_name = 'esot_250_100'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 250FPS - 150ms

dataset_name = 'esot_250_150'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 20FPS - 2ms

dataset_name = 'esot_20_2'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 20FPS - 20ms

dataset_name = 'esot_20_20'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 20FPS - 50ms

dataset_name = 'esot_20_50'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 20FPS - 100ms

dataset_name = 'esot_20_100'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - Pytracking - 20FPS - 150ms

dataset_name = 'esot_20_150'
dataset = get_dataset(dataset_name)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %% [markdown]
# **For stream-based latency-aware evaluation with pytracking's trackers:**

# %%
pytracking_trackers_stare = trackerlist('dimp', 'dimp18') + \
                            trackerlist('dimp', 'dimp18_esot500') + \
                            trackerlist('dimp', 'dimp50') + \
                            trackerlist('dimp', 'dimp50_esot500') + \
                            trackerlist('kys', 'default') + \
                            trackerlist('kys', 'esot500') + \
                            trackerlist('atom', 'default') + \
                            trackerlist('atom', 'esot500') + \
                            trackerlist('tomp', 'tomp50') + \
                            trackerlist('tomp', 'tomp50_esot500') + \
                            trackerlist('tomp', 'tomp101') + \
                            trackerlist('tomp', 'tomp101_esot500') + \
                            trackerlist('dimp', 'prdimp18') + \
                            trackerlist('dimp', 'prdimp50') + \
                            trackerlist('keep_track', 'default') + \
                            trackerlist('rts', 'rts50') + \
                            trackerlist('egt', 'egt')

trackers = []
trackers.extend(pytracking_trackers_stare)

dataset_name = 'esot500s'
dataset = get_dataset(dataset_name)

# %%
# Sim - Realtime - Pytracking - s101 - 2ms

stream_setting_id = 101

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - Pytracking - s102 - 20ms

stream_setting_id = 102

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - Pytracking - s103 - 50ms

stream_setting_id = 103

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - Pytracking - s104 - 100ms

stream_setting_id = 104

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - Pytracking - s105 - 150ms

stream_setting_id = 105

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - Pytracking - s106 - 200ms

stream_setting_id = 106

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)
