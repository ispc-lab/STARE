# %% [markdown]
# **Prepare environment:**

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import sys
import matplotlib.pyplot as plt
from pathlib import Path

plt.rcParams['figure.figsize'] = [14, 8]

work_dir = Path.cwd().parent.parent.parent
# print(work_dir)
sys.path.append(str(work_dir))
# print(sys.path)

from lib.test.analysis.plot_results import plot_results, print_results, print_per_sequence_results
from lib.test.evaluation import get_dataset, trackerlist

# %% [markdown]
# **For frame-based evaluation with OSTrack:**

# %%
# Frame-based evaluation - OSTrack - 500FPS - 2ms

dataset_name = 'esot_500_2'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 500FPS - 20ms

dataset_name = 'esot_500_20'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 500FPS - 50ms

dataset_name = 'esot_500_50'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 500FPS - 100ms

dataset_name = 'esot_500_100'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 500FPS - 150ms

dataset_name = 'esot_500_150'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 250FPS - 2ms

dataset_name = 'esot_250_2'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 250FPS - 20ms

dataset_name = 'esot_250_20'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 250FPS - 50ms

dataset_name = 'esot_250_50'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 250FPS - 100ms

dataset_name = 'esot_250_100'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 250FPS - 150ms

dataset_name = 'esot_250_150'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 20FPS - 2ms

dataset_name = 'esot_20_2'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 20FPS - 20ms

dataset_name = 'esot_20_20'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 20FPS - 50ms

dataset_name = 'esot_20_50'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 20FPS - 100ms

dataset_name = 'esot_20_100'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %%
# Frame-based evaluation - OSTrack - 20FPS - 150ms

dataset_name = 'esot_20_150'
dataset = get_dataset(dataset_name)

trackers = []
trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500mix',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
)

# %% [markdown]
# **For stream-based latency-aware evaluation with OSTrack:**

# %%
dataset_name = 'esot500s'
dataset = get_dataset(dataset_name)

trackers = []

trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500_baseline',
        dataset_name=dataset_name,
        run_ids=None,
        display_name='OSTrack',
    )
)

trackers.extend(
    trackerlist(
        name='ostrack',
        parameter_name='esot500_baseline',
        dataset_name=dataset_name,
        run_ids=66,
        display_name='OSTrack_C'
    )
)

# %%
# Sim - Realtime - OSTrack - s101 - 2ms

stream_setting_id = 101

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack - s102 - 20ms

stream_setting_id = 102

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack - s103 - 50ms

stream_setting_id = 103

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack - s104 - 100ms

stream_setting_id = 104

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack - s105 - 150ms

stream_setting_id = 105

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)

# %%
# Sim - Realtime - OSTrack - s106 - 200ms

stream_setting_id = 106

print_results(
    trackers,
    dataset,
    dataset_name,
    force_evaluation=True,
    plot_types=('success', 'prec', 'norm_prec'),
    stream_id=stream_setting_id,
)
